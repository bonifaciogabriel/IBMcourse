# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# # Data science Tools and Ecosystem

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# ![10.PNG](attachment:10.PNG)

# %% [markdown]
# Some of the key takeaways from the course
#
# **Objectives**
# - Learn Python
# - Learn about Python libraries
# - Learn how to clean, analyze and visualize data

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# Some of the popular lenguages that Data Scientists use are:
#
# - Python
# - R
# - Scala

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# Some of the commonly used libraryes by Data Scientists include:
# - Numpy
# - Pandas
# - Matplotlib

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Python             |
# | R                  |
# | Scala              |

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %% [markdown]
# ### Below are a fwe ecamples of evaluating arithmetic expessions in Python

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %%
# This is a simple atithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %%
#This will convert 200 mintutes to hours dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# ## Author
#
# Gabriel Bonifacio
